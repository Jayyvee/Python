# %% [markdown]
# # 01. Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Python Data Types

# %%
#this is the example for the tasking within the readings
x = 2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
# Code 3 different ways of reaching to 100 by addin gor subtracting 
60+40
# Out:
# 100

# %%
# 2nd example
30+70
# Out:
# 100

# %%
# 3rd example
150-50
# Out:
# 100

# %% [markdown]
# # type()

# %%
type(x)
# Out:
# int
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # Floating Point Number

# %%
# this is the example for the tasking within the readings 
y= 5.678

# %%
type(y)
# Out:
# float

# %%
# Code 2 floating point variables and divide them by each other
x= 3.5

# %%
y= 55.5

# %%
x/y
# Out:
# 0.06306306306306306

# %%
# 2nd example 
x= 6687.56

# %%
y= 894.44

# %%
x/y
# Out:
# 7.476812307141899

# %% [markdown]
# # Strings

# %%
#this is the example for the tasking within the readings
z= 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type('Mania')
# Out:
# str

# %% [markdown]
# # Boolean

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# # Procedures with Data Types: How to use Integers and floats

# %%
print (x)
# Out:
# 2

# %%
x+ 4
# Out:
# 6

# %%
x + y
# Out:
# 7.678

# %%
x= x+4

# %%
print(x)
# Out:
# 6

# %% [markdown]
# # How to use Strings

# %%
#this is the example for the tasking within the readings
a= 'Hello,'

# %%
b= ' Marley'

# %%
a + b
# Out:
# 'Hello, Marley'

# %%
# construct a short word made of separate strings

# %%
g= ' likes blue'

# %%
b + g
# Out:
# ' Marley likes blue'

# %%
# construct a short sentences made of separate strings

# %%
c= 'Hows the weather today?'

# %%
d= ' its pretty cold, a winter storm is upon us'

# %%
c+d
# Out:
# 'Hows the weather today? its pretty cold, a winter storm is upon us'

# %%
# 2nd example
e= ' Have you met the new girl at shcool?'

# %%
f= ' Yes, we went sledding togethor'

# %%
e + f
# Out:
# ' Have you met the new girl at shcool? Yes, we went sledding togethor'

# %% [markdown]
# # How to use Booleans

# %%
x==y
# Out:
# False

# %%
type(x==y)
# Out:
# bool

# %%
type(x==y)
# Out:
# bool

# %% [markdown]
# # Bonus Task

# %%
# make a string appear 100 times
b * 100
# Out:
# 'Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?Marley?'

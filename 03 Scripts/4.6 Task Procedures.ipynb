# %% [markdown]
# # Import Libraries

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Dataframes

# %%
#Identify path 
path= '../02 Data/'

# %%
#import orders products combined 
df_ords_prods_combined=pd.read_pickle(os.path.join(path,'Prepared Data','orders_products_combined.pkl'))

# %%
#import products checked
df_prods=pd.read_csv(os.path.join(path,'Prepared Data','products_checked.csv'), index_col=False)

# %% [markdown]
# ## Check Shape of dataframes

# %%
# df_orders_prods_combined shape
df_prods_combined. shape
# Out:
# (32434489, 11)

# %%
#df_prods shape
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# ## merging orders prods combined to products

# %%
df_prods_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Merging df prods combined and df prods
df_ords_prods_merge= df_prods.merge(df_prods_combined, on='product_id')

# %%
df_ords_prods_merge
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
del df_ords_prods_combined

# %%
#check the shape of the new dataframe
df_ords_prods_merge.shape
# Out:
# (32404859, 15)

# %% [markdown]
# # Export df_ords_prods_merge

# %%
# exporting data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data','ords_prods_merge.pkl'))

# %%
del df_ords_prods_combined
